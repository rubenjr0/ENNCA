JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000827.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000828.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000829.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000830.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000831.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000832.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000833.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000834.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000835.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000836.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000837.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000838.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000839.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000840.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000841.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000842.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000843.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000844.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000845.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000846.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000847.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000848.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000849.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000850.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000851.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000852.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000853.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000854.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000855.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000856.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000857.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000858.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000859.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000860.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000861.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000862.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000863.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000864.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000865.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000866.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000867.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000868.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000869.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000870.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000871.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000872.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000873.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000874.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000875.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000876.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000877.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000878.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000879.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000880.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000881.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000882.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000883.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000884.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000885.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000886.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000887.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000888.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000889.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000890.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000891.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000892.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000893.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000894.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000895.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000896.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000897.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000898.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000899.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000900.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000901.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000902.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000903.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000904.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000905.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000906.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000907.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000908.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000909.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000910.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000911.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000912.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000913.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000914.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000915.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000916.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000917.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000918.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000919.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000920.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000921.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000922.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000923.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000924.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000925.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000926.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000927.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000928.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000929.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000930.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000931.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000932.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000933.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000934.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000935.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000936.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000937.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000938.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000939.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000940.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000941.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000942.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000943.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000944.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000945.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000946.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000947.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000948.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000949.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000950.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000951.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000952.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000953.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000954.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000955.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000956.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000957.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000958.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000959.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000960.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000961.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000962.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000963.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000964.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000965.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000966.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000967.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000968.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000969.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000970.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000971.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000972.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000973.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000974.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000975.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000976.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000977.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000978.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000979.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000980.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000981.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000982.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000983.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000984.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000985.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000986.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000987.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000988.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000989.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000990.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000991.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000992.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000993.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000994.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000995.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000996.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000997.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000998.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00000999.JPEG
#   inflating: /content/calibration_data/data/ILSVRC2012_val_00001000.JPEG
#   inflating: /content/calibration_data/samples.txt

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.quantization.qconfig import QConfig
from torch.quantization.observer import MinMaxObserver, MovingAverageMinMaxObserver, MovingAveragePerChannelMinMaxObserver, PerChannelMinMaxObserver
import yaml
from torch.ao.quantization.fake_quantize import FakeQuantize
import torch
import torchvision
import os
import torch.nn as nn
import torch.ao.quantization.quantize_fx as quantize_fx
import copy

# %%
  example_inputs = (torch.randn(1, 3, 224, 224),)
  model_fp = torchvision.models.resnet18(pretrained=True)
  model_to_quantize = copy.deepcopy(model_fp)
  quantize_fx.fuse_fx(model_to_quantize.eval())
  transform_cali = transforms.Compose([
      transforms.Resize(256),
      transforms.CenterCrop(224),
      transforms.ToTensor(),  # Convert the image to a PyTorch tensor
      transforms.Normalize(
          mean=[0.485, 0.456, 0.406],  # ImageNet dataset mean
          std=[0.229, 0.224, 0.225]  # ImageNet dataset standard deviation
      )
  ])
  transform_val = transforms.Compose([
      transforms.Resize(256),
      transforms.CenterCrop(224),
      transforms.ToTensor(),  # Convert the image to a PyTorch tensor
      transforms.Normalize(
          mean=[0.485, 0.456, 0.406],  # ImageNet dataset mean
          std=[0.229, 0.224, 0.225]  # ImageNet dataset standard deviation
      )
  ])
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 133MB/s]

# %%
from PIL import Image
from torch.utils.data import Dataset
import torchvision.transforms as transforms
import random
import os

class MyDataset(Dataset):
    def __init__(self, txt_file, transform=None, dir=None):
        self.data = []
        with open(txt_file, 'r') as f:
            for line in f:
                image_path = line.split(' ')[0]
                label = line.split(' ')[1].split('\n')[0]
                self.data.append((image_path, int(label)))
        self.transform = transform
        self.dir = dir
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        if self.dir:
            image_path = os.path.join(self.dir, image_path)
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label


class CustomDataset(Dataset):
    def __init__(self, original_dataset, samples_per_epoch):
        self.original_dataset = original_dataset
        self.samples_per_epoch = samples_per_epoch

    def __getitem__(self, index):
        random_index = random.randint(0, len(self.original_dataset) - 1)
        return self.original_dataset[random_index]

    def __len__(self):
        return self.samples_per_epoch

# %%
val_dataset = MyDataset('/content/calibration_data/samples.txt',
                        transform=transform_val)

# %%
qconfig = QConfig(activation=FakeQuantize.with_args(observer=MinMaxObserver,
                                                          quant_min=0,
                                                          quant_max=255,
                                                          qscheme=torch.per_tensor_affine,
                                                          reduce_range=False,),
                        weight=FakeQuantize.with_args(observer=PerChannelMinMaxObserver,
                                                      quant_min=-128,
                                                      quant_max=127,
                                                      dtype=torch.qint8,
                                                      qscheme=torch.per_channel_symmetric,
                                                      #per_tensor_symmetric
                                                      reduce_range=False,
                                                      ch_axis=0,
                                                        ))

# %%
from torch.ao.quantization import (
  get_default_qconfig_mapping,
  get_default_qat_qconfig_mapping,
  QConfigMapping,
)
qconfig_mapping = QConfigMapping().set_global(qconfig)

# %%
model_prepared = quantize_fx.prepare_fx(model_to_quantize, qconfig_mapping, example_inputs)

# %%
criterion = nn.CrossEntropyLoss()

# %%
def evaluate_model(model, validation_dataloader, criterion, device):
    model.to(device)
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for data in validation_dataloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)

            # Compute the loss
            loss = criterion(outputs, labels)
            running_loss += loss.item()

            # Calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_loss = running_loss / len(validation_dataloader)
    accuracy = 100 * correct / total

    return avg_loss, accuracy

# %%
val_loader = DataLoader(val_dataset, batch_size=100, shuffle=False, num_workers=8, drop_last=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
loss, acc = evaluate_model(model_prepared, val_loader, criterion,'cuda')

# %%
acc
# Out:
# 69.75

# %%
model_prepared = model_prepared.to('cpu')

# %%
model_quantized = quantize_fx.convert_fx(model_prepared)

# %%
loss, acc = evaluate_model(model_quantized, val_loader, criterion,'cpu')

# %%
acc
# Out:
# 66.625

# %%
model_prepared
# Out:
# GraphModule(
#   (activation_post_process_0): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0187]), zero_point=tensor([114], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-2.1179039478302, max_val=2.640000104904175)
#   )
#   (conv1): ConvReLU2d(
#     (0): QuantizedConv2d(Reference)(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(inplace=True)
#   )
#   (activation_post_process_1): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0273]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=6.968907356262207)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (activation_post_process_2): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0273]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=6.968907356262207)
#   )
#   (layer1): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (activation_post_process_3): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0213]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=5.433541297912598)
#   )
#   (activation_post_process_4): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0517]), zero_point=tensor([141], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-7.298849105834961, max_val=5.877784729003906)
#   )
#   (activation_post_process_5): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0290]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=7.3822922706604)
#   )
#   (activation_post_process_6): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0171]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=4.36132287979126)
#   )
#   (activation_post_process_7): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0610]), zero_point=tensor([155], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-9.433801651000977, max_val=6.116794586181641)
#   )
#   (activation_post_process_8): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0349]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=8.910597801208496)
#   )
#   (layer2): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (downsample): Module(
#         (0): QuantizedConv2d(Reference)(64, 128, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (activation_post_process_9): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0166]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=4.24070930480957)
#   )
#   (activation_post_process_10): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0441]), zero_point=tensor([95], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-4.207176685333252, max_val=7.047486305236816)
#   )
#   (activation_post_process_11): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0343]), zero_point=tensor([135], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-4.641353607177734, max_val=4.094722270965576)
#   )
#   (activation_post_process_12): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0283]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=7.211561679840088)
#   )
#   (activation_post_process_13): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0199]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=5.0794172286987305)
#   )
#   (activation_post_process_14): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0434]), zero_point=tensor([141], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-6.102829933166504, max_val=4.972873687744141)
#   )
#   (activation_post_process_15): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0286]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=7.2954630851745605)
#   )
#   (layer3): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (downsample): Module(
#         (0): QuantizedConv2d(Reference)(128, 256, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (activation_post_process_16): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0150]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=3.836390972137451)
#   )
#   (activation_post_process_17): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0406]), zero_point=tensor([92], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-3.7141711711883545, max_val=6.627476215362549)
#   )
#   (activation_post_process_18): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0167]), zero_point=tensor([169], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-2.8219733238220215, max_val=1.4427917003631592)
#   )
#   (activation_post_process_19): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0267]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=6.810975551605225)
#   )
#   (activation_post_process_20): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0194]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=4.936844825744629)
#   )
#   (activation_post_process_21): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0503]), zero_point=tensor([154], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-7.742077827453613, max_val=5.073171615600586)
#   )
#   (activation_post_process_22): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0300]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=7.6541876792907715)
#   )
#   (layer4): Module(
#     (0): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (downsample): Module(
#         (0): QuantizedConv2d(Reference)(256, 512, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): Module(
#       (conv1): ConvReLU2d(
#         (0): QuantizedConv2d(Reference)(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (conv2): QuantizedConv2d(Reference)(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (activation_post_process_23): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0141]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=3.5952749252319336)
#   )
#   (activation_post_process_24): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0431]), zero_point=tensor([111], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-4.772782802581787, max_val=6.208411693572998)
#   )
#   (activation_post_process_25): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0266]), zero_point=tensor([121], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-3.2209134101867676, max_val=3.5685651302337646)
#   )
#   (activation_post_process_26): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0314]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=8.008794784545898)
#   )
#   (activation_post_process_27): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.0128]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=3.257014274597168)
#   )
#   (activation_post_process_28): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.2951]), zero_point=tensor([57], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-16.894067764282227, max_val=58.34833908081055)
#   )
#   (activation_post_process_29): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.2493]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=63.574275970458984)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (activation_post_process_30): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.2493]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=63.574275970458984)
#   )
#   (activation_post_process_31): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.2493]), zero_point=tensor([0], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=0.0, max_val=63.574275970458984)
#   )
#   (fc): QuantizedLinear(Reference)(in_features=512, out_features=1000, bias=True)
#   (activation_post_process_32): FakeQuantize(
#     fake_quant_enabled=tensor([1], dtype=torch.uint8), observer_enabled=tensor([1], dtype=torch.uint8), quant_min=0, quant_max=255, dtype=torch.quint8, qscheme=torch.per_tensor_affine, ch_axis=-1, scale=tensor([0.1720]), zero_point=tensor([65], dtype=torch.int32)
#     (activation_post_process): MinMaxObserver(min_val=-11.161824226379395, max_val=32.69382858276367)
#   )
# )

# %% [markdown]
# #TASK:
# 1. Split the 1000 samples into two groups, 50%,50%, one of them will be named calibration_dataset while the other will be validation_dataset. You should use calibration dataset to calibrate scale and zero point before performing actual quantization.
# 2. Make PTQ training for MobileNetV2, using PerchannelMinMax Quantization for weights and PerTensorMinMax Quantization separately.
# 3. Make Perchannel MovingAverageMinMax Quantization for weights and MovingAverage Pertensor Quantization for activation. Compare to results in 2., Check which one is better. Compare some scales and zero points of from the observers. Explain why one of the solution is better?

# %% [markdown]
# # 1. Split
# We use pytorch's `random_split` function to split the data on two datasets, each one containing a 50% of the original datasets' data.

# %%
from torch.utils.data import random_split
calibration_dataset, validation_dataset = random_split(val_dataset, (0.5, 0.5))

# %% [markdown]
# # 2. PTQ training for MobileNetV2

# %% [markdown]
# # 2.1 PerChannelMinMax

# %%
model_mnv2 = torchvision.models.quantization.mobilenet_v2(pretrained=True)
model_to_quantize = copy.deepcopy(model_mnv2)
quantize_fx.fuse_fx(model_to_quantize.eval())
qconfig = QConfig(activation=FakeQuantize.with_args(observer=MinMaxObserver,
                                                    quant_min=0,
                                                    quant_max=255,
                                                    qscheme=torch.per_tensor_affine,
                                                    reduce_range=False,),
                  weight=FakeQuantize.with_args(observer=PerChannelMinMaxObserver,
                                              quant_min=-128,
                                              quant_max=127,
                                              dtype=torch.qint8,
                                              qscheme=torch.per_channel_symmetric,
                                              #per_tensor_symmetric
                                              reduce_range=False,
                                              ch_axis=0,
                                              ))
qconfig_mapping = QConfigMapping().set_global(qconfig)
model_prepared = quantize_fx.prepare_fx(model_to_quantize, qconfig_mapping, example_inputs)
calibration_loader = DataLoader(calibration_dataset, batch_size=100, shuffle=False, num_workers=8, drop_last=True)
loss, acc = evaluate_model(model_prepared, calibration_loader, criterion,'cuda')
print('Loss:', loss)
print('Accuracy:', acc)
model_prepared = model_prepared.to('cpu')
model_quantized = quantize_fx.convert_fx(model_prepared)
validation_loader = DataLoader(validation_dataset, batch_size=100, shuffle=False, num_workers=8, drop_last=True)
loss, acc = evaluate_model(model_quantized, validation_loader, criterion,'cpu')
print('Quantized loss:', loss)
print('Quantized accuracy:', acc)
# Out:
# Loss: 1.0652364492416382
# Accuracy: 70.75
# Quantized loss: 1.530437707901001
# Quantized accuracy: 63.25

# %% [markdown]
# # 2.2 PerTensorMinMax

# %%
model_mnv2 = torchvision.models.quantization.mobilenet_v2(pretrained=True)
model_to_quantize = copy.deepcopy(model_mnv2)
quantize_fx.fuse_fx(model_to_quantize.eval())
qconfig = QConfig(activation=FakeQuantize.with_args(observer=MinMaxObserver,
                                                    quant_min=0,
                                                    quant_max=255,
                                                    qscheme=torch.per_tensor_affine,
                                                    reduce_range=False,),
                  weight=FakeQuantize.with_args(observer=MinMaxObserver,
                                              quant_min=-128,
                                              quant_max=127,
                                              dtype=torch.qint8,
                                              qscheme=torch.per_tensor_symmetric,
                                              #per_tensor_symmetric
                                              reduce_range=False,
                                              ))
qconfig_mapping = QConfigMapping().set_global(qconfig)
model_prepared = quantize_fx.prepare_fx(model_to_quantize, qconfig_mapping, example_inputs)
calibration_loader = DataLoader(calibration_dataset, batch_size=100, shuffle=False, num_workers=8, drop_last=True)
loss, acc = evaluate_model(model_prepared, calibration_loader, criterion,'cuda')
print('Loss:', loss)
print('Accuracy:', acc)
model_prepared = model_prepared.to('cpu')
model_quantized = quantize_fx.convert_fx(model_prepared)
validation_loader = DataLoader(validation_dataset, batch_size=100, shuffle=False, num_workers=8, drop_last=True)
loss, acc = evaluate_model(model_quantized, validation_loader, criterion,'cpu')
print('Quantized loss:', loss)
print('Quantized accuracy:', acc)
# Out:
# Loss: 1.0652364492416382
# Accuracy: 70.75
# Quantized loss: 1.3668818175792694
# Quantized accuracy: 67.5

# %% [markdown]
# # 3. Moving average

# %%
model_mnv2 = torchvision.models.quantization.mobilenet_v2(pretrained=True)
model_to_quantize = copy.deepcopy(model_mnv2)
quantize_fx.fuse_fx(model_to_quantize.eval())
qconfig = QConfig(activation=FakeQuantize.with_args(observer=MovingAverageMinMaxObserver,
                                                    quant_min=0,
                                                    quant_max=255,
                                                    qscheme=torch.per_tensor_affine,
                                                    reduce_range=False,),
                  weight=FakeQuantize.with_args(observer=MovingAveragePerChannelMinMaxObserver,
                                              quant_min=-128,
                                              quant_max=127,
                                              dtype=torch.qint8,
                                              qscheme=torch.per_channel_symmetric,
                                              #per_tensor_symmetric
                                              reduce_range=False,
                                              ch_axis=0
                                              ))
qconfig_mapping = QConfigMapping().set_global(qconfig)
model_prepared = quantize_fx.prepare_fx(model_to_quantize, qconfig_mapping, example_inputs)
calibration_loader = DataLoader(calibration_dataset, batch_size=100, shuffle=False, num_workers=8, drop_last=True)
loss, acc = evaluate_model(model_prepared, calibration_loader, criterion,'cuda')
print('Loss:', loss)
print('Accuracy:', acc)
model_prepared = model_prepared.to('cpu')
model_quantized = quantize_fx.convert_fx(model_prepared)
validation_loader = DataLoader(validation_dataset, batch_size=100, shuffle=False, num_workers=8, drop_last=True)
loss, acc = evaluate_model(model_quantized, validation_loader, criterion,'cpu')
print('Quantized loss:', loss)
print('Quantized accuracy:', acc)
# Out:
# Loss: 1.0440984219312668
# Accuracy: 71.5
# Quantized loss: 1.5116087198257446
# Quantized accuracy: 65.25

# %% [markdown]
# # Conclussions
#
# The best result can be observed when using `PerTensorMinMax` (point 2.2) on the weights.
#
# The second best result can be observed when using the moving averaged observers (point 3).
#
# If we compare the quantized accuracy to pre-quantization accuracy we can get have a better idea of what settings performed better:
#
# - 2.1: $\frac{63.25}{70.75} \approx 0.89$
#
# - 2.2: $\frac{67.5}{70.75} \approx 0.95$
#
# - 3: $\frac{65.25}{71.5} \approx 0.91$
